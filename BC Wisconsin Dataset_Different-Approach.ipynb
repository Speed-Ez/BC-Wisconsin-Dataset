# %% [markdown]
# ## **Breast Cancer Wisconsin (Diagnostic) Dataset**
#
# ### **Source: UCI Machine Learning Repository**

# %% [markdown]
# **Aim:**
#
# Use the following machine learning algorithms to predict which patient breast scan can be diagnosed as benign or malignant;
#
# 1. **Logistic Regression**
# 2. **Neural Network**
# 3. **Random Forest**
# 4. **Support Vector Machine**
# 5. **Xgboost**
#
# Rank them by the best performing algorithm.

# %% [markdown]
# **MetaData**
#
# Here’s a quick rundown of what the variables typically represent:
# - **`ID number`**:ID number for each case record
# - **`Diagnosis`**: (M = malignant, B = benign)
#
# Other variable meaning
# - **`radius`**: (mean of distances from center to points on the perimeter)
# - **`texture`**: (standard deviation of gray-scale values)
# - **`perimeter`**:
# - **`area`**:
# - **`smoothness`**: (local variation in radius lengths)
# - **`compactness`**: (perimeter^2 / area - 1.0)
# - **`concavity`**: (severity of concave portions of the contour)
# - **`concave points`**: (number of concave portions of the contour)
# - **`symmetry`**:
# - **`fractal dimension`**: ("coastline approximation" - 1)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
# Importing the data along with the variable names
var_names=['ID','Diagnosis','radius1','texture1','perimeter1','area1','smoothness1','compactness1','concavity1','concave_points1',
      'symmetry1','fractal_dimension1','radius2','texture2','perimeter2','area2','smoothness2','compactness2','concavity2','concave_points2',
      'symmetry2','fractal_dimension2','radius3','texture3','perimeter3','area3','smoothness3','compactness3','concavity3','concave_points3',
      'symmetry3','fractal_dimension3']
dt=pd.read_csv(r'H:\Documents\Data Projects\CodeAnt\breast+cancer+wisconsin+diagnostic\wdbc.data',names=var_names)
dt
# Out:
#            ID Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0      842302         M    17.99     10.38      122.80  1001.0      0.11840
# 1      842517         M    20.57     17.77      132.90  1326.0      0.08474
# 2    84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 3    84348301         M    11.42     20.38       77.58   386.1      0.14250
# 4    84358402         M    20.29     14.34      135.10  1297.0      0.10030
# ..        ...       ...      ...       ...         ...     ...          ...
# 564    926424         M    21.56     22.39      142.00  1479.0      0.11100
# 565    926682         M    20.13     28.25      131.20  1261.0      0.09780
# 566    926954         M    16.60     28.08      108.30   858.1      0.08455
# 567    927241         M    20.60     29.33      140.10  1265.0      0.11780
# 568     92751         B     7.76     24.54       47.92   181.0      0.05263
#
#      compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0         0.27760     0.30010          0.14710  ...   25.380     17.33
# 1         0.07864     0.08690          0.07017  ...   24.990     23.41
# 2         0.15990     0.19740          0.12790  ...   23.570     25.53
# 3         0.28390     0.24140          0.10520  ...   14.910     26.50
# 4         0.13280     0.19800          0.10430  ...   22.540     16.67
# ..            ...         ...              ...  ...      ...       ...
# 564       0.11590     0.24390          0.13890  ...   25.450     26.40
# 565       0.10340     0.14400          0.09791  ...   23.690     38.25
# 566       0.10230     0.09251          0.05302  ...   18.980     34.12
# 567       0.27700     0.35140          0.15200  ...   25.740     39.42
# 568       0.04362     0.00000          0.00000  ...    9.456     30.37
#
#      perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0        184.60  2019.0      0.16220       0.66560      0.7119
# 1        158.80  1956.0      0.12380       0.18660      0.2416
# 2        152.50  1709.0      0.14440       0.42450      0.4504
# 3         98.87   567.7      0.20980       0.86630      0.6869
# 4        152.20  1575.0      0.13740       0.20500      0.4000
# ..          ...     ...          ...           ...         ...
# 564      166.10  2027.0      0.14100       0.21130      0.4107
# 565      155.00  1731.0      0.11660       0.19220      0.3215
# 566      126.70  1124.0      0.11390       0.30940      0.3403
# 567      184.60  1821.0      0.16500       0.86810      0.9387
# 568       59.16   268.6      0.08996       0.06444      0.0000
#
#      concave_points3  symmetry3  fractal_dimension3
# 0             0.2654     0.4601             0.11890
# 1             0.1860     0.2750             0.08902
# 2             0.2430     0.3613             0.08758
# 3             0.2575     0.6638             0.17300
# 4             0.1625     0.2364             0.07678
# ..               ...        ...                 ...
# 564           0.2216     0.2060             0.07115
# 565           0.1628     0.2572             0.06637
# 566           0.1418     0.2218             0.07820
# 567           0.2650     0.4087             0.12400
# 568           0.0000     0.2871             0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# In the Breast Cancer Wisconsin (Diagnostic) dataset:
#
# - **M = Malignant**: This represents cancerous tumors that are invasive and potentially life-threatening. Malignant tumors grow aggressively, invade surrounding tissues, and may spread to other parts of the body.
#
# - **B = Benign:** This represents non-cancerous tumors that are not invasive. Benign tumors are generally less harmful, do not invade nearby tissues, and do not spread to other parts of the body.
#
# These labels form the target variable, which is the focus of classification tasks in the dataset. The goal is to use the features in the dataset to accurately classify tumors as either M or B.

# %%
# Data overview
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  569 non-null    int64
#  1   Diagnosis           569 non-null    object
#  2   radius1             569 non-null    float64
#  3   texture1            569 non-null    float64
#  4   perimeter1          569 non-null    float64
#  5   area1               569 non-null    float64
#  6   smoothness1         569 non-null    float64
#  7   compactness1        569 non-null    float64
#  8   concavity1          569 non-null    float64
#  9   concave_points1     569 non-null    float64
#  10  symmetry1           569 non-null    float64
#  11  fractal_dimension1  569 non-null    float64
#  12  radius2             569 non-null    float64
#  13  texture2            569 non-null    float64
#  14  perimeter2          569 non-null    float64
#  15  area2               569 non-null    float64
#  16  smoothness2         569 non-null    float64
#  17  compactness2        569 non-null    float64
#  18  concavity2          569 non-null    float64
#  19  concave_points2     569 non-null    float64
#  20  symmetry2           569 non-null    float64
#  21  fractal_dimension2  569 non-null    float64
#  22  radius3             569 non-null    float64
#  23  texture3            569 non-null    float64
#  24  perimeter3          569 non-null    float64
#  25  area3               569 non-null    float64
#  26  smoothness3         569 non-null    float64
#  27  compactness3        569 non-null    float64
#  28  concavity3          569 non-null    float64
#  29  concave_points3     569 non-null    float64
#  30  symmetry3           569 non-null    float64
#  31  fractal_dimension3  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %% [markdown]
# **The data has 569 entries with no missing values**

# %%
dt.duplicated().any()
# Out:
# False

# %% [markdown]
# **There are no duplicate values**

# %%
# Summary Statistics
dt.describe().T
# Out:
#                     count          mean           std          min  \
# ID                  569.0  3.037183e+07  1.250206e+08  8670.000000
# radius1             569.0  1.412729e+01  3.524049e+00     6.981000
# texture1            569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter1          569.0  9.196903e+01  2.429898e+01    43.790000
# area1               569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness1         569.0  9.636028e-02  1.406413e-02     0.052630
# compactness1        569.0  1.043410e-01  5.281276e-02     0.019380
# concavity1          569.0  8.879932e-02  7.971981e-02     0.000000
# concave_points1     569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry1           569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension1  569.0  6.279761e-02  7.060363e-03     0.049960
# radius2             569.0  4.051721e-01  2.773127e-01     0.111500
# texture2            569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter2          569.0  2.866059e+00  2.021855e+00     0.757000
# area2               569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness2         569.0  7.040979e-03  3.002518e-03     0.001713
# compactness2        569.0  2.547814e-02  1.790818e-02     0.002252
# concavity2          569.0  3.189372e-02  3.018606e-02     0.000000
# concave_points2     569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry2           569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension2  569.0  3.794904e-03  2.646071e-03     0.000895
# radius3             569.0  1.626919e+01  4.833242e+00     7.930000
# texture3            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter3          569.0  1.072612e+02  3.360254e+01    50.410000
# area3               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness3         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness3        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity3          569.0  2.721885e-01  2.086243e-01     0.000000
# concave_points3     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry3           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension3  569.0  8.394582e-02  1.806127e-02     0.055040
#
#                               25%            50%           75%           max
# ID                  869218.000000  906024.000000  8.813129e+06  9.113205e+08
# radius1                 11.700000      13.370000  1.578000e+01  2.811000e+01
# texture1                16.170000      18.840000  2.180000e+01  3.928000e+01
# perimeter1              75.170000      86.240000  1.041000e+02  1.885000e+02
# area1                  420.300000     551.100000  7.827000e+02  2.501000e+03
# smoothness1              0.086370       0.095870  1.053000e-01  1.634000e-01
# compactness1             0.064920       0.092630  1.304000e-01  3.454000e-01
# concavity1               0.029560       0.061540  1.307000e-01  4.268000e-01
# concave_points1          0.020310       0.033500  7.400000e-02  2.012000e-01
# symmetry1                0.161900       0.179200  1.957000e-01  3.040000e-01
# fractal_dimension1       0.057700       0.061540  6.612000e-02  9.744000e-02
# radius2                  0.232400       0.324200  4.789000e-01  2.873000e+00
# texture2                 0.833900       1.108000  1.474000e+00  4.885000e+00
# perimeter2               1.606000       2.287000  3.357000e+00  2.198000e+01
# area2                   17.850000      24.530000  4.519000e+01  5.422000e+02
# smoothness2              0.005169       0.006380  8.146000e-03  3.113000e-02
# compactness2             0.013080       0.020450  3.245000e-02  1.354000e-01
# concavity2               0.015090       0.025890  4.205000e-02  3.960000e-01
# concave_points2          0.007638       0.010930  1.471000e-02  5.279000e-02
# symmetry2                0.015160       0.018730  2.348000e-02  7.895000e-02
# fractal_dimension2       0.002248       0.003187  4.558000e-03  2.984000e-02
# radius3                 13.010000      14.970000  1.879000e+01  3.604000e+01
# texture3                21.080000      25.410000  2.972000e+01  4.954000e+01
# perimeter3              84.110000      97.660000  1.254000e+02  2.512000e+02
# area3                  515.300000     686.500000  1.084000e+03  4.254000e+03
# smoothness3              0.116600       0.131300  1.460000e-01  2.226000e-01
# compactness3             0.147200       0.211900  3.391000e-01  1.058000e+00
# concavity3               0.114500       0.226700  3.829000e-01  1.252000e+00
# concave_points3          0.064930       0.099930  1.614000e-01  2.910000e-01
# symmetry3                0.250400       0.282200  3.179000e-01  6.638000e-01
# fractal_dimension3       0.071460       0.080040  9.208000e-02  2.075000e-01

# %% [markdown]
# ### **Before proceeding, let us create a new column that will contain the encoded values of the target variable**

# %%
le=LabelEncoder()
dt['Diagnosis']=le.fit_transform(dt['Diagnosis'])
dt
# Out:
#            ID  Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0      842302          1    17.99     10.38      122.80  1001.0      0.11840
# 1      842517          1    20.57     17.77      132.90  1326.0      0.08474
# 2    84300903          1    19.69     21.25      130.00  1203.0      0.10960
# 3    84348301          1    11.42     20.38       77.58   386.1      0.14250
# 4    84358402          1    20.29     14.34      135.10  1297.0      0.10030
# ..        ...        ...      ...       ...         ...     ...          ...
# 564    926424          1    21.56     22.39      142.00  1479.0      0.11100
# 565    926682          1    20.13     28.25      131.20  1261.0      0.09780
# 566    926954          1    16.60     28.08      108.30   858.1      0.08455
# 567    927241          1    20.60     29.33      140.10  1265.0      0.11780
# 568     92751          0     7.76     24.54       47.92   181.0      0.05263
#
#      compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0         0.27760     0.30010          0.14710  ...   25.380     17.33
# 1         0.07864     0.08690          0.07017  ...   24.990     23.41
# 2         0.15990     0.19740          0.12790  ...   23.570     25.53
# 3         0.28390     0.24140          0.10520  ...   14.910     26.50
# 4         0.13280     0.19800          0.10430  ...   22.540     16.67
# ..            ...         ...              ...  ...      ...       ...
# 564       0.11590     0.24390          0.13890  ...   25.450     26.40
# 565       0.10340     0.14400          0.09791  ...   23.690     38.25
# 566       0.10230     0.09251          0.05302  ...   18.980     34.12
# 567       0.27700     0.35140          0.15200  ...   25.740     39.42
# 568       0.04362     0.00000          0.00000  ...    9.456     30.37
#
#      perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0        184.60  2019.0      0.16220       0.66560      0.7119
# 1        158.80  1956.0      0.12380       0.18660      0.2416
# 2        152.50  1709.0      0.14440       0.42450      0.4504
# 3         98.87   567.7      0.20980       0.86630      0.6869
# 4        152.20  1575.0      0.13740       0.20500      0.4000
# ..          ...     ...          ...           ...         ...
# 564      166.10  2027.0      0.14100       0.21130      0.4107
# 565      155.00  1731.0      0.11660       0.19220      0.3215
# 566      126.70  1124.0      0.11390       0.30940      0.3403
# 567      184.60  1821.0      0.16500       0.86810      0.9387
# 568       59.16   268.6      0.08996       0.06444      0.0000
#
#      concave_points3  symmetry3  fractal_dimension3
# 0             0.2654     0.4601             0.11890
# 1             0.1860     0.2750             0.08902
# 2             0.2430     0.3613             0.08758
# 3             0.2575     0.6638             0.17300
# 4             0.1625     0.2364             0.07678
# ..               ...        ...                 ...
# 564           0.2216     0.2060             0.07115
# 565           0.1628     0.2572             0.06637
# 566           0.1418     0.2218             0.07820
# 567           0.2650     0.4087             0.12400
# 568           0.0000     0.2871             0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# #### Analyze the relationships among features to understand their interaction and contribution to the target variable.

# %%
#Checking correlation
corrl=dt.select_dtypes(include='number').corr()
corrl
# Out:
#                           ID  Diagnosis   radius1  texture1  perimeter1  \
# ID                  1.000000   0.039769  0.074626  0.099770    0.073159
# Diagnosis           0.039769   1.000000  0.730029  0.415185    0.742636
# radius1             0.074626   0.730029  1.000000  0.323782    0.997855
# texture1            0.099770   0.415185  0.323782  1.000000    0.329533
# perimeter1          0.073159   0.742636  0.997855  0.329533    1.000000
# area1               0.096893   0.708984  0.987357  0.321086    0.986507
# smoothness1        -0.012968   0.358560  0.170581 -0.023389    0.207278
# compactness1        0.000096   0.596534  0.506124  0.236702    0.556936
# concavity1          0.050080   0.696360  0.676764  0.302418    0.716136
# concave_points1     0.044158   0.776614  0.822529  0.293464    0.850977
# symmetry1          -0.022114   0.330499  0.147741  0.071401    0.183027
# fractal_dimension1 -0.052511  -0.012838 -0.311631 -0.076437   -0.261477
# radius2             0.143048   0.567134  0.679090  0.275869    0.691765
# texture2           -0.007526  -0.008303 -0.097317  0.386358   -0.086761
# perimeter2          0.137331   0.556141  0.674172  0.281673    0.693135
# area2               0.177742   0.548236  0.735864  0.259845    0.744983
# smoothness2         0.096781  -0.067016 -0.222600  0.006614   -0.202694
# compactness2        0.033961   0.292999  0.206000  0.191975    0.250744
# concavity2          0.055239   0.253730  0.194204  0.143293    0.228082
# concave_points2     0.078768   0.408042  0.376169  0.163851    0.407217
# symmetry2          -0.017306  -0.006522 -0.104321  0.009127   -0.081629
# fractal_dimension2  0.025725   0.077972 -0.042641  0.054458   -0.005523
# radius3             0.082405   0.776454  0.969539  0.352573    0.969476
# texture3            0.064720   0.456903  0.297008  0.912045    0.303038
# perimeter3          0.079986   0.782914  0.965137  0.358040    0.970387
# area3               0.107187   0.733825  0.941082  0.343546    0.941550
# smoothness3         0.010338   0.421465  0.119616  0.077503    0.150549
# radius1                    0.744214   0.163953            0.007066
# texture1                   0.295316   0.105008            0.119205
# perimeter1                 0.771241   0.189115            0.051019
# area1                      0.722017   0.143570            0.003738
# smoothness1                0.503053   0.394309            0.499316
# compactness1               0.815573   0.510223            0.687382
# concavity1                 0.861323   0.409464            0.514930
# concave_points1            0.910155   0.375744            0.368661
# symmetry1                  0.430297   0.699826            0.438413
# fractal_dimension1         0.175325   0.334019            0.767297
# radius2                    0.531062   0.094543            0.049559
# texture2                  -0.119638  -0.128215           -0.045655
# perimeter2                 0.554897   0.109930            0.085433
# area2                      0.538166   0.074126            0.017539
# smoothness2               -0.102007  -0.107342            0.101480
# compactness2               0.483208   0.277878            0.590973
# concavity2                 0.440472   0.197788            0.439329
# concave_points2            0.602450   0.143116            0.310655
# symmetry2                 -0.030413   0.389402            0.078079
# fractal_dimension2         0.215204   0.111094            0.591328
# radius3                    0.787424   0.243529            0.093492
# texture3                   0.359755   0.233027            0.219122
# perimeter3                 0.816322   0.269493            0.138957
# area3                      0.747419   0.209146            0.079647
# smoothness3                0.547691   0.493838            0.617624
# compactness3               0.801080   0.614441            0.810455
# concavity3                 0.855434   0.532520            0.686511
# concave_points3            1.000000   0.502528            0.511114
# symmetry3                  0.502528   1.000000            0.537848
# fractal_dimension3         0.511114   0.537848            1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(8, 7))
sns.heatmap(corrl)
plt.title('Variable Correlations')
plt.show()

# %% [markdown]
# #### **The Heatmap has not shown any visible known correlation between the features and the target**

# %%
# Lets look at the distrinution of the classes in the target variable (Diagnosis)
tar_dis=dt['Diagnosis'].value_counts()
tar_dis
# Out:
# Diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
tar_dis.plot(kind='pie', autopct='%1.2f%%')
plt.title('class distribution for Diagnosis column')
plt.show()

# %% [markdown]
# We see a slight class imbalance with a ratio of **B[63% : 37%]M**. To achieve a more balance class, we carry out a hybrid sampling method

# %%
dt.head()
# Out:
#          ID  Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842302          1    17.99     10.38      122.80  1001.0      0.11840
# 1    842517          1    20.57     17.77      132.90  1326.0      0.08474
# 2  84300903          1    19.69     21.25      130.00  1203.0      0.10960
# 3  84348301          1    11.42     20.38       77.58   386.1      0.14250
# 4  84358402          1    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.27760      0.3001          0.14710  ...    25.38     17.33
# 1       0.07864      0.0869          0.07017  ...    24.99     23.41
# 2       0.15990      0.1974          0.12790  ...    23.57     25.53
# 3       0.28390      0.2414          0.10520  ...    14.91     26.50
# 4       0.13280      0.1980          0.10430  ...    22.54     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0      184.60  2019.0       0.1622        0.6656      0.7119           0.2654
# 1      158.80  1956.0       0.1238        0.1866      0.2416           0.1860
# 2      152.50  1709.0       0.1444        0.4245      0.4504           0.2430
# 3       98.87   567.7       0.2098        0.8663      0.6869           0.2575
# 4      152.20  1575.0       0.1374        0.2050      0.4000           0.1625
#
#    symmetry3  fractal_dimension3
# 0     0.4601             0.11890
# 1     0.2750             0.08902
# 2     0.3613             0.08758
# 3     0.6638             0.17300
# 4     0.2364             0.07678
#
# [5 rows x 32 columns]

# %%
#Now let us seperate our features matrix from the target variable
# (m) for features
# (n) for target
mre = dt.drop(columns=['Diagnosis'], axis=1)
nre = dt['Diagnosis']

# %%
mre.head()
# Out:
#          ID  radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    842302    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    842517    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2  84300903    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3  84348301    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4  84358402    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  ...  radius3  texture3  perimeter3  \
# 0      0.3001          0.14710     0.2419  ...    25.38     17.33      184.60
# 1      0.0869          0.07017     0.1812  ...    24.99     23.41      158.80
# 2      0.1974          0.12790     0.2069  ...    23.57     25.53      152.50
# 3      0.2414          0.10520     0.2597  ...    14.91     26.50       98.87
# 4      0.1980          0.10430     0.1809  ...    22.54     16.67      152.20
#
#     area3  smoothness3  compactness3  concavity3  concave_points3  symmetry3  \
# 0  2019.0       0.1622        0.6656      0.7119           0.2654     0.4601
# 1  1956.0       0.1238        0.1866      0.2416           0.1860     0.2750
# 2  1709.0       0.1444        0.4245      0.4504           0.2430     0.3613
# 3   567.7       0.2098        0.8663      0.6869           0.2575     0.6638
# 4  1575.0       0.1374        0.2050      0.4000           0.1625     0.2364
#
#    fractal_dimension3
# 0             0.11890
# 1             0.08902
# 2             0.08758
# 3             0.17300
# 4             0.07678
#
# [5 rows x 31 columns]

# %%
nre
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: Diagnosis, Length: 569, dtype: int32

# %%
# Now, we split further into training and test sets
from sklearn.model_selection import train_test_split

# Importing algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# Import metrics
from sklearn.metrics import accuracy_score

# %%
mre_train,mre_test,nre_train,nre_test = train_test_split(mre,nre,train_size=0.80,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
mre_train=sc.fit_transform(mre_train)
mre_test= sc.transform(mre_test)

#After Normalization, the result is an array, you have to convert it back to a DataFrame
mre_train = pd.DataFrame(mre_train, columns=mre.columns)
mre_test = pd.DataFrame(mre_test, columns=mre.columns)

mre_train
# Out:
#            ID   radius1  texture1  perimeter1     area1  smoothness1  \
# 0    0.000933  0.065527  0.257694    0.077323  0.034369     0.487226
# 3    9.864924e-04  0.230619  0.269530    0.238654  0.127607     0.476393
# 4    1.001273e-03  0.188501  0.159959    0.190141  0.099760     0.426198
# ..            ...       ...       ...         ...       ...          ...
# 109  9.921842e-04  0.340320  0.241461    0.329279  0.212649     0.304956
# 110  9.438584e-03  0.410353  0.336152    0.399630  0.277740     0.352532
# 111  9.610061e-04  0.187521  0.176530    0.184592  0.101219     0.439379
# 112  9.594490e-04  0.319751  0.613460    0.317470  0.194585     0.267220
# 113  9.764617e-02  0.638572  0.724045    0.624413  0.535742     0.379706
#
#      compactness1  concavity1  concave_points1  symmetry1  ...   radius3  \
# 0        0.295939    0.187559         0.189911   0.404698  ...  0.229954
# 1        0.286008    0.253046         0.395179   0.221570  ...  0.591404
# 2        0.352442    0.343486         0.401938   0.407902  ...  0.386741
# 3        0.384289    0.181373         0.139115   0.343833  ...  0.153571
# 4        0.317170    0.157849         0.128926   0.347571  ...  0.130911
# ..            ...         ...              ...        ...  ...       ...
# 109      0.163003    0.121649         0.138718   0.129204  ...  0.284409
# 110      0.222108    0.228889         0.329920   0.336893  ...  0.405380
# 111      0.201014    0.101406         0.145577   0.382274  ...  0.145165
# 112      0.289432    0.258435         0.219085   0.093433  ...  0.258461
# 113      0.325046    0.320291         0.429722   0.321410  ...  0.870258
#
#      texture3  perimeter3     area3  smoothness3  compactness3  concavity3  \
# 0    0.336354    0.211275  0.112718     0.485159      0.231175    0.213339
# 1    0.388060    0.566367  0.407503     0.326903      0.226562    0.214617
# 2    0.372601    0.357938  0.231342     0.566664      0.232932    0.302796
# 3    0.290245    0.178537  0.072499     0.501460      0.258739    0.191933
# 4    0.204158    0.123481  0.058108     0.430143      0.202622    0.143530
# ..        ...         ...       ...          ...           ...         ...
# 109  0.357676    0.261858  0.150705     0.292264      0.197351    0.194649
# 110  0.334222    0.377764  0.247965     0.535421      0.194606    0.225958
# 111  0.244403    0.134157  0.066544     0.460029      0.143761    0.144089
# 112  0.760128    0.244065  0.134081     0.250832      0.236446    0.244728
# 113  0.936567    0.810889  0.796050     0.468179      0.260386    0.274920
#
#      concave_points3  symmetry3  fractal_dimension3
# 0           0.348797   0.285630            0.275178
# 1           0.614777   0.194362            0.091980
# 2           0.520275   0.250739            0.213208
# 3           0.253265   0.195348            0.326806
# 4           0.237732   0.150601            0.222957
# ..               ...        ...                 ...
# 109         0.269003   0.175439            0.092574
# 110         0.522337   0.213877            0.074856
# 111         0.330172   0.216637            0.195405
# 112         0.282440   0.064065            0.194303
# 113         0.570103   0.256850            0.230078
#
# [114 rows x 31 columns]

# %%
rus = RandomUnderSampler()
(mre_train,nre_train)=rus.fit_resample(mre_train,nre_train)
ax = nre_train.value_counts().plot.pie(autopct = '%.2f')
title = ax.set_title("Under-sampling")

# %%
ros = RandomOverSampler()
(mre_train,nre_train)=ros.fit_resample(mre_train,nre_train)
ax = nre_train.value_counts().plot.pie(autopct = '%.2f')
title = ax.set_title("Over-sampling")

# %% [markdown]
# I have resampled the train set of the  Features matrix (mre_train) and the Target variable (nre_train)

# %%
# Create a dictionary to print out the results
results = {}

# %% [markdown]
# ### **Logistic Regression model**

# %%
def lrm(mre_train,nre_train,mre_test):
    lrm = LogisticRegression(max_iter=1000)
    lrm = lrm.fit(mre_train,nre_train)
    lrm_pred = lrm.predict(mre_test)
    return lrm_pred

# %%
results['Logistic_Regression_Accuracy'] = accuracy_score(nre_test,lrm(mre_train,nre_train,mre_test))

# %% [markdown]
# ### **Neural Network Model**

# %%
nnm = MLPClassifier(max_iter=1000)
nnm = nnm.fit(mre_train,nre_train)
# learning score
nnm.score(mre_train,nre_train)
# Out:
# 0.9881656804733728

# %%
# Making prediction
nnm_pred = nnm.predict(mre_test)

# %%
results['Neural Network Accuracy'] = accuracy_score(nre_test,nnm_pred)

# %% [markdown]
# ### **Random Forest Model**

# %%
rfm = RandomForestClassifier()
rfm = rfm.fit(mre_train,nre_train)
# learning score
rfm.score(mre_train,nre_train)
# Out:
# 1.0

# %%
# Making prediction
rfm_pred = rfm.predict(mre_test)

# %%
results['Random Forest Accuracy'] = accuracy_score(nre_test,rfm_pred)

# %% [markdown]
# ### **Support Vector Machine Model**

# %%
svmm = SVC()
svmm = svmm.fit(mre_train,nre_train)
# learning score
svmm.score(mre_train,nre_train)
# Out:
# 0.9763313609467456

# %%
# Making prediction
svmm_pred = svmm.predict(mre_test)

# %%
results['Support Vector Machine Accuracy'] = accuracy_score(nre_test,svmm_pred)

# %% [markdown]
# ### **Gradient Boosting Model**

# %%
gbm = GradientBoostingClassifier()
gbm = gbm.fit(mre_train,nre_train)
# learning score
gbm.score(mre_train,nre_train)
# Out:
# 1.0

# %%
# Making prediction
gbm_pred = gbm.predict(mre_test)

# %%
results['Gradient Boosting Model Accuracy'] = accuracy_score(nre_test,gbm_pred)

# %%
results
# Out:
# {'Logistic_Regression_Accuracy': 0.9824561403508771,
#  'Neural Network Accuracy': 0.9649122807017544,
#  'Random Forest Accuracy': 0.9736842105263158,
#  'Support Vector Machine Accuracy': 0.9736842105263158,
#  'Gradient Boosting Model Accuracy': 0.9736842105263158}

# %%
# Sorting the models by perfomance in descending order
results = dict(sorted(results.items(), key = lambda item: item[1], reverse = True))
results
# Out:
# {'Logistic_Regression_Accuracy': 0.9824561403508771,
#  'Random Forest Accuracy': 0.9736842105263158,
#  'Support Vector Machine Accuracy': 0.9736842105263158,
#  'Gradient Boosting Model Accuracy': 0.9736842105263158,
#  'Neural Network Accuracy': 0.9649122807017544}

# %%
for i, score in results.items():
    print(f"{i} : {score * 100: .0f}%")
# Out:
# Logistic_Regression_Accuracy :  98%
# Random Forest Accuracy :  97%
# Support Vector Machine Accuracy :  97%
# Gradient Boosting Model Accuracy :  97%
# Neural Network Accuracy :  96%

# %% [markdown]
# <span style="font-size:15px; color:red">**Previous Accuracy Scores before Data Normalization**</span>
#
# <span style="color:red">Random Forest Accuracy :  97%</span>
#
# <span style="color:red">Gradient Boosting Model Accuracy :  97%</span>
#
# <span style="color:red">Logistic_Regression_Accuracy :  92%</span>
#
# <span style="color:red">Support Vector Machine Accuracy :  55%</span>
#
# <span style="color:red">Neural Network Accuracy :  52%</span>

# %% [markdown]
# ## **Findings**
# **Feature Correlation Analysis:**
#
# A heatmap was generated to visualize the correlations between features and the target variable. Observation: No clear or strong correlations were observed between individual features and the target, suggesting that relationships may be non-linear or involve complex interactions.
#
#
# **Key Observations:**
#
# **`Random Forest and Gradient Boosting`**: This model likely captured complex, non-linear relationships between features effectively. Tree-based models like Gradient Boosting and Random Forest are not sensitive to feature scaling.
#
#
# **`Logistic Regression`**: Previously delivered an accuracy of 92%, showing that some linear relationships exist within the data. Now accuracy score of 98%. Logistic Regression uses a linear boundary, and normalization makes optimization more efficient, improving accuracy.
#
#
# **`Support Vector Machine (SVM) and Neural Network`**: Previously performed poorly with an accuracy of 53% and 49% respectively, suggests hyperparameters may not be well-suited for this dataset. Has now achieved 97% accuracy
#
# Neural Networks are sensitive to the scale of input features. Normalization ensures all features are on the same scale, improving convergence and enabling the model to learn more effectively.
#
# SVM depends on the distance between data points and the hyperplane, which is affected by feature scaling. Normalizing the data ensures better separation of classes.
#
#
#
# **Inference:**
#
# The **`linear relationship`** mentioned refers to the assumption in Logistic Regression that there is a direct, linear relationship between the independent features (predictor variables) and the log-odds of the target variable (Diagnosis)
#
# **`Logistic Regression`** works well when features have this kind of straightforward influence. But if the relationship is more complex (e.g., radius_mean affects the outcome differently when combined with another feature), Logistic Regression may miss those patterns. This is why models like **`Random Forest`** and **`Gradient Boosting`**, which handle complex relationships, perform better in this case.

# %% [markdown]
# ### **Why did Heatmap not show any correlation?**
#
# - The heatmap only visualizes linear correlations between features and the target. If there are no strong linear relationships (correlation values near +1 or -1), the heatmap will not show anything significant.
# - However, Logistic Regression works with log-odds and can still identify patterns even if the heatmap does not show strong linear relationships.
#
# The heatmap uses Pearson correlation, which only measures direct linear relationships. If the relationships are weak, indirect, or involve interactions between features, the heatmap won't show them. Models like Logistic Regression and Random Forest can pick up these subtle patterns in the data, which explains their performance.

# %% [markdown]
# ### **Verifying Accuracy?**
#
# To ensure the model is not overfitting, we evaluating it with metrics like:
#
# - cross-validation scores
# - Confusion matrix
# - classification report

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### **Cross_V/Confusion_M/Classifcation_R (Logistic Regression)**

# %%
lg=LogisticRegression()
score=cross_val_score(lg,mre,nre,cv=5,scoring='accuracy')
score*100
# Out:
# C:\Users\GODSPEED\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\GODSPEED\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\GODSPEED\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\GODSPEED\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([93.85964912, 92.98245614, 90.35087719, 92.10526316, 87.61061947])

# %%
print(classification_report(nre_test,lrm(mre_train,nre_train,mre_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
ConfusionMatrixDisplay(confusion_matrix(nre_test,lrm(mre_train,nre_train,mre_test))).plot()

# %% [markdown]
# ### **Cross_V/Confusion_M/Classifcation_R (Support Vector Machine)**

# %%
svm=SVC()
score=cross_val_score(svm,mre,nre,cv=5,scoring='accuracy')
score*100
# Out:
# array([60.52631579, 55.26315789, 63.15789474, 61.40350877, 62.83185841])

# %%
print(classification_report(nre_test,svmm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
ConfusionMatrixDisplay(confusion_matrix(nre_test,svmm_pred)).plot()

# %% [markdown]
# ### **Cross_V/Confusion_M/Classifcation_R (Neural Network)**

# %%
nn=MLPClassifier(max_iter=1000)
score=cross_val_score(nn,mre,nre,cv=5,scoring='accuracy')
score*100
# Out:
# array([62.28070175, 37.71929825, 36.84210526, 75.43859649, 37.16814159])

# %%
print(classification_report(nre_test,nnm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        71
#            1       0.93      0.98      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.97      0.96       114
# weighted avg       0.97      0.96      0.97       114

# %%
ConfusionMatrixDisplay(confusion_matrix(nre_test,nnm_pred)).plot()

# %% [markdown]
# ### **Cross_V/Confusion_M/Classifcation_R (Random Forest)**

# %%
rf=RandomForestClassifier()
score=cross_val_score(rf,mre,nre,cv=5,scoring='accuracy')
score*100
# Out:
# array([92.98245614, 94.73684211, 98.24561404, 96.49122807, 97.34513274])

# %%
print(classification_report(nre_test,rfm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
ConfusionMatrixDisplay(confusion_matrix(nre_test,rfm_pred)).plot()

# %% [markdown]
# ### **Cross_V/Confusion_M/Classifcation_R (Gradient Boosting)**

# %%
gb=GradientBoostingClassifier()
score=cross_val_score(gb,mre,nre,cv=5,scoring='accuracy')
score*100
# Out:
# array([92.98245614, 93.85964912, 97.36842105, 97.36842105, 96.46017699])

# %%
print(classification_report(nre_test,gbm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
ConfusionMatrixDisplay(confusion_matrix(nre_test,gbm_pred)).plot()

# %% [markdown]
# **After normalizing the data, all models, including Neural Networks, SVM, Gradient Boosting, and Random Forest, achieved high accuracy (97%), demonstrating strong predictive performance for breast cancer diagnosis. Logistic Regression also performed well at 95%. This highlights the importance of preprocessing, particularly normalization, in optimizing model accuracy.**
